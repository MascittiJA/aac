# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np


def dibujar(lista, eje, nombre, titulo):
    objects = ('Main', 'FIFO', 'RAND', 'LRU', 'LFU')
    y_pos = np.arange(len(objects))
    performance = lista

    plt.bar(y_pos, performance, align='center', alpha=0.5, color='blue')
    plt.xticks(y_pos, objects)
    plt.ylabel(eje)
    plt.title(titulo)

    plt.savefig(nombre)
    plt.show()

    
def dibujar2(lista, eje, nombre, titulo):
    objects = ('FIFO', 'RAND', 'LRU', 'LFU')
    y_pos = np.arange(len(objects))
    performance = lista

    plt.bar(y_pos, performance, align='center', alpha=0.5, color='blue')
    plt.xticks(y_pos, objects)
    plt.ylabel(eje)
    plt.title(titulo)

    plt.savefig(nombre)
    plt.show()

def dibujar3(lista, eje, nombre, titulo):
    objects = ('FIFO', 'RAND', 'LRU', 'LFU')
    y_pos = np.arange(len(objects))
    performance = lista

    plt.bar(y_pos, performance, align='center', alpha=0.5, color='blue')
    plt.xticks(y_pos, objects)
    plt.ylabel(eje)
    plt.title(titulo)

    plt.savefig(nombre)
    plt.show()

# %%
valores = [451.99813199043274, 93.10810494422913, 93.05641198158264, 93.01834893226624, 93.0265200138092]
dibujar(valores, 'Time (sec)', 'secuentialTime.jpg', 'Secuential Reading Time')

valores = [0.875, 0.875, 0.875, 0.875]
dibujar2(valores, 'HitRate', 'secuentialHitRate.jpg', 'Secuential Reading HitRate')

# %%
valores = [452.10125041007996, 452.25261759757996, 452.215624332428, 452.3504858016968, 452.35599541664124]
dibujar(valores, 'Time (sec)', 'randomTime.jpg', 'Random Reading Time')

valores = [0.4375, 0.4375, 0.4376220703125, 0.4375]
dibujar2(valores, 'HitRate', 'randomHitRate.jpg', 'Random Reading HitRate')

# %%
valores = [2147.040258407593, 633.7358212471008, 493.0050415992737, 634.0770735740662, 352.9531834125519]
dibujar(valores, 'Time (sec)', 'fifoTime.jpg', 'Reading Time')

valores = [0.7763157894736842, 0.8486328125, 0.7763157894736842, 0.9204872532894737]
dibujar2(valores, 'HitRate', 'fifoHitRate.jpg', 'Reading HitRate')

# %%
(, 0.8405797101449275, , 0.8414855072463768, , 0.9107789855072463, , 0.9107789855072463, 487.234281539917, 0)

valores = [115.4329354763031, 115.08279061317444, 84.43494367599487, 84.4746663570404]
dibujar3(valores, 'Time (sec)', 'lruTime.jpg', 'Reading Time')

valores = [0.8179535308441559, 0.8483664772727273, 0.850395698051948, 0.9217989042207793]
dibujar2(valores, 'HitRate', 'lruHitRate.jpg', 'Reading HitRate')

# %%
valores = [621.7053198814392, 117.76256775856018, 168.70570421218872, 82.68478989601135, 121.67278981208801]
dibujar(valores, 'Time (sec)', 'lfuTime.jpg', 'Reading Time')

valores = [0.8273481889204546, 0.8426846590909091, 0.8635031960227273, 0.9173473011363636]
dibujar2(valores, 'HitRate', 'lfuHitRate.jpg', 'Reading HitRate')

# %%
objects = ('Write Through', 'Copy Back')
y_pos = np.arange(len(objects))
performance = [1019.8541641235352, 312.7770073413849]

plt.bar(y_pos, performance, align='center', alpha=0.5, color='blue')
plt.xticks(y_pos, objects)
plt.ylabel('Time (sec)')
plt.title('Writing Time')

plt.savefig('writeTime.jpg')
plt.show()


objects = ('Write Through', 'Copy Back')
y_pos = np.arange(len(objects))
performance = [0.859375, 0.859375]

plt.bar(y_pos, performance, align='center', alpha=0.5, color='blue')
plt.xticks(y_pos, objects)
plt.ylabel('Hit Rate')
plt.title('Writing HitRate')

plt.savefig('writeHitRate.jpg')
plt.show()

# %%
valores = [452.057669878006, 452.08130717277527, 452.24421668052673, 452.28463196754456, 452.25419092178345]
dibujar(valores, 'Time (sec)', 'randomTime.jpg', 'Random Reading Time')

valores = [ 0.000244140625, 0, 0, 0]
dibujar2(valores, 'HitRate', 'randomHitRate.jpg', 'Random Reading HitRate')
